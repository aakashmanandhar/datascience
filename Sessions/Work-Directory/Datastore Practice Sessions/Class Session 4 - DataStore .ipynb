# %%
csvfile = open('../../Data/Pokemon.csv', 'r')

# %%
reader = csv.reader

# %%
csvfile.read()
# Out:
# "#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n3,VenusaurMega Venusaur,Grass,Poison,625,80,100,123,122,120,80,1,False\n4,Charmander,Fire,,309,39,52,43,60,50,65,1,False\n5,Charmeleon,Fire,,405,58,64,58,80,65,80,1,False\n6,Charizard,Fire,Flying,534,78,84,78,109,85,100,1,False\n6,CharizardMega Charizard X,Fire,Dragon,634,78,130,111,130,85,100,1,False\n6,CharizardMega Charizard Y,Fire,Flying,634,78,104,78,159,115,100,1,False\n7,Squirtle,Water,,314,44,48,65,50,64,43,1,False\n8,Wartortle,Water,,405,59,63,80,65,80,58,1,False\n9,Blastoise,Water,,530,79,83,100,85,105,78,1,False\n9,BlastoiseMega Blastoise,Water,,630,79,103,120,135,115,78,1,False\n10,Caterpie,Bug,,195,45,30,35,20,20,45,1,False\n11,Metapod,Bug,,205,50,20,55,25,25,30,1,False\n12,Butterfree,Bug,Flying,395,60,45,50,90,80,70,1
# ...

# %%
csvfile.seek(0)
# Out:
# 0

# %%
csvfile.read()
# Out:
# "#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n3,VenusaurMega Venusaur,Grass,Poison,625,80,100,123,122,120,80,1,False\n4,Charmander,Fire,,309,39,52,43,60,50,65,1,False\n5,Charmeleon,Fire,,405,58,64,58,80,65,80,1,False\n6,Charizard,Fire,Flying,534,78,84,78,109,85,100,1,False\n6,CharizardMega Charizard X,Fire,Dragon,634,78,130,111,130,85,100,1,False\n6,CharizardMega Charizard Y,Fire,Flying,634,78,104,78,159,115,100,1,False\n7,Squirtle,Water,,314,44,48,65,50,64,43,1,False\n8,Wartortle,Water,,405,59,63,80,65,80,58,1,False\n9,Blastoise,Water,,530,79,83,100,85,105,78,1,False\n9,BlastoiseMega Blastoise,Water,,630,79,103,120,135,115,78,1,False\n10,Caterpie,Bug,,195,45,30,35,20,20,45,1,False\n11,Metapod,Bug,,205,50,20,55,25,25,30,1,False\n12,Butterfree,Bug,Flying,395,60,45,50,90,80,70,1
# ...

# %%
csvfile.read(500)
# Out:
# '#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n3,VenusaurMega Venusaur,Grass,Poison,625,80,100,123,122,120,80,1,False\n4,Charmander,Fire,,309,39,52,43,60,50,65,1,False\n5,Charmeleon,Fire,,405,58,64,58,80,65,80,1,False\n6,Charizard,Fire,Flying,534,78,84,78,109,85,100,1,False\n6,CharizardMega Chariza'

# %%
csvfile.read(500)
# Out:
# ''

# %%
csvfile.seek(0)
# Out:
# 0

# %%
csvfile.readlines()
# Out:
# ['#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n',
#  '1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n',
#  '2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n',
#  '3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n',
#  '3,VenusaurMega Venusaur,Grass,Poison,625,80,100,123,122,120,80,1,False\n',
#  '4,Charmander,Fire,,309,39,52,43,60,50,65,1,False\n',
#  '5,Charmeleon,Fire,,405,58,64,58,80,65,80,1,False\n',
#  '6,Charizard,Fire,Flying,534,78,84,78,109,85,100,1,False\n',
#  '6,CharizardMega Charizard X,Fire,Dragon,634,78,130,111,130,85,100,1,False\n',
#  '6,CharizardMega Charizard Y,Fire,Flying,634,78,104,78,159,115,100,1,False\n',
#  '7,Squirtle,Water,,314,44,48,65,50,64,43,1,False\n',
#  '8,Wartortle,Water,,405,59,63,80,65,80,58,1,False\n',
#  '9,Blastoise,Water,,530,79,83,100,85,105,78,1,False\n',
#  '9,BlastoiseMega Blastoise,Water,,630,79,103,120,135,115,78,1,False\n',
# ...

# %%
csvfile.seek(0)
# Out:
# 0

# %%
csvfile.readline()
# Out:
# '#,Name,Type 1,Type 2,Total,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary\n'

# %%
csvfile.readline()
# Out:
# '1,Bulbasaur,Grass,Poison,318,45,49,49,65,65,45,1,False\n'

# %%
csvfile.readline()
# Out:
# '2,Ivysaur,Grass,Poison,405,60,62,63,80,80,60,1,False\n'

# %%
line = csvfile.readline()

# %%
line
# Out:
# '3,Venusaur,Grass,Poison,525,80,82,83,100,100,80,1,False\n'

# %%
line.strip().split(',')
# Out:
# ['3',
#  'Venusaur',
#  'Grass',
#  'Poison',
#  '525',
#  '80',
#  '82',
#  '83',
#  '100',
#  '100',
#  '80',
#  '1',
#  'False']

# %%
csvfile.close()

# %%
import csv

# %%
with open('../../Data/Pokemon.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for line in reader:
        print(line[1], line[3])
# Out:
# Name Type 2
# Bulbasaur Poison
# Ivysaur Poison
# Venusaur Poison
# VenusaurMega Venusaur Poison
# Charmander
# Charmeleon
# Charizard Flying
# CharizardMega Charizard X Dragon
# CharizardMega Charizard Y Flying
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree Flying
# Weedle Poison
# Kakuna Poison
# Beedrill Poison
# BeedrillMega Beedrill Poison
# Pidgey Flying
# Pidgeotto Flying
# Pidgeot Flying
# PidgeotMega Pidgeot Flying
# Rattata
# Raticate
# Spearow Flying
# Fearow Flying
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran♀
# Nidorina
# Nidoqueen Ground
# Nidoran♂
# Nidorino
# Nidoking Ground
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff Fairy
# Wigglytuff Fairy
# Zubat Flying
# Golbat Flying
# Oddish Poison
# Gloom Poison
# Vileplume Poison
# Paras Grass
# Parasect Grass
# Venonat Poison
# Venomoth Poison
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# ...

# %%
fieldnames = ['#','Name','Type 1','Type 2','Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Generation','Legendary']

# %%
with open('../../Data/Pokemon.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=fieldnames)
    for line in reader:
        print(line['Name'], line['Type 2'])
# Out:
# Name Type 2
# Bulbasaur Poison
# Ivysaur Poison
# Venusaur Poison
# VenusaurMega Venusaur Poison
# Charmander
# Charmeleon
# Charizard Flying
# CharizardMega Charizard X Dragon
# CharizardMega Charizard Y Flying
# Squirtle
# Wartortle
# Blastoise
# BlastoiseMega Blastoise
# Caterpie
# Metapod
# Butterfree Flying
# Weedle Poison
# Kakuna Poison
# Beedrill Poison
# BeedrillMega Beedrill Poison
# Pidgey Flying
# Pidgeotto Flying
# Pidgeot Flying
# PidgeotMega Pidgeot Flying
# Rattata
# Raticate
# Spearow Flying
# Fearow Flying
# Ekans
# Arbok
# Pikachu
# Raichu
# Sandshrew
# Sandslash
# Nidoran♀
# Nidorina
# Nidoqueen Ground
# Nidoran♂
# Nidorino
# Nidoking Ground
# Clefairy
# Clefable
# Vulpix
# Ninetales
# Jigglypuff Fairy
# Wigglytuff Fairy
# Zubat Flying
# Golbat Flying
# Oddish Poison
# Gloom Poison
# Vileplume Poison
# Paras Grass
# Parasect Grass
# Venonat Poison
# Venomoth Poison
# Diglett
# Dugtrio
# Meowth
# Persian
# Psyduck
# Golduck
# Mankey
# Primeape
# Growlithe
# ...

# %%
import json

# %%
_jsn = {'Name': 'Wartortle'}

# %%
_jsn
# Out:
# {'Name': 'Wartortle'}

# %%
json.dumps(_jsn)
# Out:
# '{"Name": "Wartortle"}'

# %%
json.loads('{"Name": "Wartortle"}')
# Out:
# {'Name': 'Wartortle'}

# %%
data = {
    'pokemons': []
}
with open('../../Data/Pokemon.csv', 'r') as csvfile:
    reader = csv.DictReader(csvfile, fieldnames=fieldnames)
    next(reader)
    for line in reader:
        data['pokemons'].append(line)
with open('../../Data/Pokemon.json', 'w') as jsonfile:
    json.dump(data, jsonfile)

# %%
_jsonfile = open('../../Data/Pokemon.json', 'r')
_json = json.load(_jsonfile)

# %%
_json
# Out:
# {'pokemons': [{'#': '1',
#    'Attack': '49',
#    'Defense': '49',
#    'Generation': '1',
#    'HP': '45',
#    'Legendary': 'False',
#    'Name': 'Bulbasaur',
#    'Sp. Atk': '65',
#    'Sp. Def': '65',
#    'Speed': '45',
#    'Total': '318',
#    'Type 1': 'Grass',
#    'Type 2': 'Poison'},
#   {'#': '2',
#    'Attack': '62',
#    'Defense': '63',
#    'Generation': '1',
#    'HP': '60',
#    'Legendary': 'False',
#    'Name': 'Ivysaur',
#    'Sp. Atk': '80',
#    'Sp. Def': '80',
#    'Speed': '60',
#    'Total': '405',
#    'Type 1': 'Grass',
#    'Type 2': 'Poison'},
#   {'#': '3',
#    'Attack': '82',
#    'Defense': '83',
#    'Generation': '1',
#    'HP': '80',
#    'Legendary': 'False',
#    'Name': 'Venusaur',
#    'Sp. Atk': '100',
#    'Sp. Def': '100',
#    'Speed': '80',
#    'Total': '525',
#    'Type 1': 'Grass',
#    'Type 2': 'Poison'},
#   {'#': '3',
#    'Attack': '100',
#    'Defense': '123',
#    'Generation': '1',
#    'HP': '80',
#    'Legendary': 'False',
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect('../../Data/db.sqlite3')

# %%
conn

# %%
cursor = conn.cursor()

# %%
cursor

# %%
sql = """CREATE TABLE pokemons(id INTEGER primary key, attack INETGER, defence INTEGER,
          generation INETEGR, hp INETEGR, legendary BOOLEAN, name TEXT, sp_at INTEGER, sp_def INTEGER, speed INTEGER, total INTEGER, type1 TEXT, type2 TEXT)"""

# %%
cursor.execute(sql)

# %%
conn.commit()

# %%
sql = """INSERT INTO pokemons(id, attack, defence, generation, hp, legendary, name, 
        sp_at, sp_def, speed, total, type1, type2)
        VALUES
        (1, 49, 49, 1, 45, 0, 'Bulbasur', 65, 65, 45, 318, 'Grass', 'Poision')"""

# %%
cursor.execute(sql)

# %%
conn.commit()

# %%
_jsonfile.close()

# %%
sql = """INSERT INTO pokemons(id, attack, defence, generation, hp, legendary, name, 
        sp_at, sp_def, speed, total, type1, type2)
        VALUES
        (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"""

# %%
with open('../../Data/Pokemon.json', 'r') as _jsonfile:
    _json = json.load(_jsonfile)
    for each in _json['pokemons']:
        values = (each['#'], each['Attack']. each['defence'], each['generation'], each['hp'], each['legendary'], each['name'], each['sp_at'], each['sp_def'], 
                            each['speed'], each['total'], 
                               each['type1'], each['type2'])
        cursor.execute(sql, values)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-eb685a469966> in <module>()
#       2     _json = json.load(_jsonfile)
#       3     for each in _json['pokemons']:
# ----> 4         values = (each['#'], each['Attack']. each['defence'], each['generation'], each['hp'], each['legendary'], each['name'], each['sp_at'], each['sp_def'],
#       5                             each['speed'], each['total'],
#       6                                each['type1'], each['type2'])
#
# AttributeError: 'str' object has no attribute 'each'
