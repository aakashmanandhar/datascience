# %% [markdown]
# ## Session - 6 Pandas

# %%
import pandas as pd

# %%
dataframe = pd.read_csv('../../Data/Weather.csv')  #Here dataframe is the variable

# %%
dataframe #Multi-Column datas are called DATAFRAME
# Out:
#           Station  Minimum  Maximum Rainfall
# 0         Dipayal     24.6     30.0      3.2
# 1      Dadeldhura     17.1     21.4     13.0
# 2        Dhangadi     24.9     31.4     18.8
# 3   Birendranagar     22.8     30.3      0.3
# 4       Nepalgunj     25.2     33.7      1.2
# 5           Jumla     15.5     19.0     13.7
# 6            Dang     23.2     31.8      0.4
# 7         Pokhara     21.4     30.4     19.3
# 8      Bhairahawa     25.2     35.2     15.9
# 9          Simara     25.2     34.0      0.0
# 10      Kathmandu     20.5     30.4      1.3
# 11    Okhaldhunga     17.5     26.4      0.0
# 12      Taplejung     18.3     27.0      2.6
# 13       Dhankuta     20.9     29.8      7.1
# 14     Biratnagar     26.3     34.5      0.0
# 15         Jomsom     12.2     20.5     2.2*
# 16         Dharan     25.0     32.5     1.4*
# 17          Lumle     16.8     25.0    47.4*
# 18       Jankapur     27.0     34.6  Traces*
# 19           Jiri     16.9     25.0     0.2*

# %%
dataframe2 = pd.read_csv('../../Data/Pokemon.csv')

# %%
dataframe2
# Out:
#        #                       Name    Type 1  Type 2  Total   HP  Attack  \
# 0      1                  Bulbasaur     Grass  Poison    318   45      49
# 1      2                    Ivysaur     Grass  Poison    405   60      62
# 2      3                   Venusaur     Grass  Poison    525   80      82
# 3      3      VenusaurMega Venusaur     Grass  Poison    625   80     100
# 4      4                 Charmander      Fire     NaN    309   39      52
# 5      5                 Charmeleon      Fire     NaN    405   58      64
# 6      6                  Charizard      Fire  Flying    534   78      84
# 7      6  CharizardMega Charizard X      Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y      Fire  Flying    634   78     104
# 9      7                   Squirtle     Water     NaN    314   44      48
# 10     8                  Wartortle     Water     NaN    405   59      63
# 11     9                  Blastoise     Water     NaN    530   79      83
# ...

# %%
dataframe.head() #head function lists top 5
# Out:
#          Station  Minimum  Maximum Rainfall
# 0        Dipayal     24.6     30.0      3.2
# 1     Dadeldhura     17.1     21.4     13.0
# 2       Dhangadi     24.9     31.4     18.8
# 3  Birendranagar     22.8     30.3      0.3
# 4      Nepalgunj     25.2     33.7      1.2

# %%
dataframe.head(10) #Selects top 10
# Out:
#          Station  Minimum  Maximum Rainfall
# 0        Dipayal     24.6     30.0      3.2
# 1     Dadeldhura     17.1     21.4     13.0
# 2       Dhangadi     24.9     31.4     18.8
# 3  Birendranagar     22.8     30.3      0.3
# 4      Nepalgunj     25.2     33.7      1.2
# 5          Jumla     15.5     19.0     13.7
# 6           Dang     23.2     31.8      0.4
# 7        Pokhara     21.4     30.4     19.3
# 8     Bhairahawa     25.2     35.2     15.9
# 9         Simara     25.2     34.0      0.0

# %%
dataframe["Station"] #Series is a single column data
# Out:
# 0           Dipayal
# 1        Dadeldhura
# 2          Dhangadi
# 3     Birendranagar
# 4         Nepalgunj
# 5             Jumla
# 6              Dang
# 7           Pokhara
# 8        Bhairahawa
# 9            Simara
# 10        Kathmandu
# 11      Okhaldhunga
# 12        Taplejung
# 13         Dhankuta
# 14       Biratnagar
# 15           Jomsom
# 16           Dharan
# 17            Lumle
# 18         Jankapur
# 19             Jiri
# Name: Station, dtype: object

# %%
series = dataframe["Station"]

# %%
series
# Out:
# 0           Dipayal
# 1        Dadeldhura
# 2          Dhangadi
# 3     Birendranagar
# 4         Nepalgunj
# 5             Jumla
# 6              Dang
# 7           Pokhara
# 8        Bhairahawa
# 9            Simara
# 10        Kathmandu
# 11      Okhaldhunga
# 12        Taplejung
# 13         Dhankuta
# 14       Biratnagar
# 15           Jomsom
# 16           Dharan
# 17            Lumle
# 18         Jankapur
# 19             Jiri
# Name: Station, dtype: object

# %%
dir(series)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
series[0] #Selection of data of 0 index
# Out:
# 'Dipayal'

# %%
dataframe[0:10]
# Out:
#          Station  Minimum  Maximum Rainfall
# 0        Dipayal     24.6     30.0      3.2
# 1     Dadeldhura     17.1     21.4     13.0
# 2       Dhangadi     24.9     31.4     18.8
# 3  Birendranagar     22.8     30.3      0.3
# 4      Nepalgunj     25.2     33.7      1.2
# 5          Jumla     15.5     19.0     13.7
# 6           Dang     23.2     31.8      0.4
# 7        Pokhara     21.4     30.4     19.3
# 8     Bhairahawa     25.2     35.2     15.9
# 9         Simara     25.2     34.0      0.0

# %%
dataframe["Station": "Maximum"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-354e6abe642d> in <module>()
# ----> 1 dataframe["Station": "Maximum"]
#
# /home/aakashm/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2048
#    2049         # see if we can slice the rows
# -> 2050         indexer = convert_to_index_sliceable(self, key)
#    2051         if indexer is not None:
#    2052             return self._getitem_slice(indexer)
#
# /home/aakashm/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in convert_to_index_sliceable(obj, key)
#    1894     idx = obj.index
#    1895     if isinstance(key, slice):
# -> 1896         return idx._convert_slice_indexer(key, kind='getitem')
#    1897
#    1898     elif isinstance(key, compat.string_types):
#
# ...

# %%
dataframe[:, "Station", "Maximum"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-99d96af192ac> in <module>()
# ----> 1 dataframe[:, "Station", "Maximum"]
#
# /home/aakashm/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /home/aakashm/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /home/aakashm/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...

# %%
dataframe[["Station", "Maximum"]]
# Out:
#           Station  Maximum
# 0         Dipayal     30.0
# 1      Dadeldhura     21.4
# 2        Dhangadi     31.4
# 3   Birendranagar     30.3
# 4       Nepalgunj     33.7
# 5           Jumla     19.0
# 6            Dang     31.8
# 7         Pokhara     30.4
# 8      Bhairahawa     35.2
# 9          Simara     34.0
# 10      Kathmandu     30.4
# 11    Okhaldhunga     26.4
# 12      Taplejung     27.0
# 13       Dhankuta     29.8
# 14     Biratnagar     34.5
# 15         Jomsom     20.5
# 16         Dharan     32.5
# 17          Lumle     25.0
# 18       Jankapur     34.6
# 19           Jiri     25.0

# %%
help(dataframe.loc) #Labeled Based Location
# Out:
# Help on _LocIndexer in module pandas.core.indexing object:
#
# class _LocIndexer(_LocationIndexer)
#  |  Purely label-location based indexer for selection by label.
#  |
#  |  ``.loc[]`` is primarily label based, but may also be used with a
#  |  boolean array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - A single label, e.g. ``5`` or ``'a'``, (note that ``5`` is
#  |    interpreted as a *label* of the index, and **never** as an
#  |    integer position along the index).
#  |  - A list or array of labels, e.g. ``['a', 'b', 'c']``.
#  |  - A slice object with labels, e.g. ``'a':'f'`` (note that contrary
#  |    to usual python slices, **both** the start and the stop are included!).
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series, DataFrame
#  |    or Panel) and that returns valid output for indexing (one of the above)
#  |
#  |  ``.loc`` will raise a ``KeyError`` when the items are not found.
#  |
# ...

# %%
help(dataframe.iloc) #Integer Based Location
# Out:
# Help on _iLocIndexer in module pandas.core.indexing object:
#
# class _iLocIndexer(_LocationIndexer)
#  |  Purely integer-location based indexing for selection by position.
#  |
#  |  ``.iloc[]`` is primarily integer position based (from ``0`` to
#  |  ``length-1`` of the axis), but may also be used with a boolean
#  |  array.
#  |
#  |  Allowed inputs are:
#  |
#  |  - An integer, e.g. ``5``.
#  |  - A list or array of integers, e.g. ``[4, 3, 0]``.
#  |  - A slice object with ints, e.g. ``1:7``.
#  |  - A boolean array.
#  |  - A ``callable`` function with one argument (the calling Series, DataFrame
#  |    or Panel) and that returns valid output for indexing (one of the above)
#  |
#  |  ``.iloc`` will raise ``IndexError`` if a requested indexer is
#  |  out-of-bounds, except *slice* indexers which allow out-of-bounds
#  |  indexing (this conforms with python/numpy *slice* semantics).
#  |
#  |  See more at :ref:`Selection by Position <indexing.integer>`
#  |
# ...

# %%
dataframe.head()
# Out:
#          Station  Minimum  Maximum Rainfall
# 0        Dipayal     24.6     30.0      3.2
# 1     Dadeldhura     17.1     21.4     13.0
# 2       Dhangadi     24.9     31.4     18.8
# 3  Birendranagar     22.8     30.3      0.3
# 4      Nepalgunj     25.2     33.7      1.2

# %%
dataframe.loc[0] #Returns all the data of Index/Location 0
# Out:
# Station     Dipayal
# Minimum        24.6
# Maximum          30
# Rainfall        3.2
# Name: 0, dtype: object

# %%
dataframe.loc[4]
# Out:
# Station     Nepalgunj
# Minimum          25.2
# Maximum          33.7
# Rainfall          1.2
# Name: 4, dtype: object

# %%
dataframe.iloc[0]
# Out:
# Station     Dipayal
# Minimum        24.6
# Maximum          30
# Rainfall        3.2
# Name: 0, dtype: object

# %%
ndf = dataframe[4:8]

# %%
ndf
# Out:
#      Station  Minimum  Maximum Rainfall
# 4  Nepalgunj     25.2     33.7      1.2
# 5      Jumla     15.5     19.0     13.7
# 6       Dang     23.2     31.8      0.4
# 7    Pokhara     21.4     30.4     19.3

# %%
ndf.iloc[0]
# Out:
# Station     Nepalgunj
# Minimum          25.2
# Maximum          33.7
# Rainfall          1.2
# Name: 4, dtype: object

# %%
ndf.loc[4]
# Out:
# Station     Nepalgunj
# Minimum          25.2
# Maximum          33.7
# Rainfall          1.2
# Name: 4, dtype: object

# %%
dataframe.head(10)
# Out:
#          Station  Minimum  Maximum Rainfall
# 0        Dipayal     24.6     30.0      3.2
# 1     Dadeldhura     17.1     21.4     13.0
# 2       Dhangadi     24.9     31.4     18.8
# 3  Birendranagar     22.8     30.3      0.3
# 4      Nepalgunj     25.2     33.7      1.2
# 5          Jumla     15.5     19.0     13.7
# 6           Dang     23.2     31.8      0.4
# 7        Pokhara     21.4     30.4     19.3
# 8     Bhairahawa     25.2     35.2     15.9
# 9         Simara     25.2     34.0      0.0

# %%
dataframe.loc[5, "Station"]
# Out:
# 'Jumla'

# %%
dataframe.loc[4:8, "Station"]
# Out:
# 4     Nepalgunj
# 5         Jumla
# 6          Dang
# 7       Pokhara
# 8    Bhairahawa
# Name: Station, dtype: object

# %%
dataframe.loc[4:8, "Station": "Rainfall"]
# Out:
#       Station  Minimum  Maximum Rainfall
# 4   Nepalgunj     25.2     33.7      1.2
# 5       Jumla     15.5     19.0     13.7
# 6        Dang     23.2     31.8      0.4
# 7     Pokhara     21.4     30.4     19.3
# 8  Bhairahawa     25.2     35.2     15.9

# %%
mdf = dataframe.loc[4:8, ["Station", "Rainfall"]]

# %%
mdf1 = dataframe2.loc[4:16, ["Name", "Total"]]

# %%
mdf
# Out:
#       Station Rainfall
# 4   Nepalgunj      1.2
# 5       Jumla     13.7
# 6        Dang      0.4
# 7     Pokhara     19.3
# 8  Bhairahawa     15.9

# %%
mdf1
# Out:
#                          Name  Total
# 4                  Charmander    309
# 5                  Charmeleon    405
# 6                   Charizard    534
# 7   CharizardMega Charizard X    634
# 8   CharizardMega Charizard Y    634
# 9                    Squirtle    314
# 10                  Wartortle    405
# 11                  Blastoise    530
# 12    BlastoiseMega Blastoise    630
# 13                   Caterpie    195
# 14                    Metapod    205
# 15                 Butterfree    395
# 16                     Weedle    195

# %%
mdf.sum()
# Out:
# Station     NepalgunjJumlaDangPokharaBhairahawa
# Rainfall                     1.213.70.419.315.9
# dtype: object

# %%
mdf.mean()
# Out:
# Series([], dtype: float64)

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 4 to 8
# Data columns (total 2 columns):
# Station     5 non-null object
# Rainfall    5 non-null object
# dtypes: object(2)
# memory usage: 164.0+ bytes

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
# Station     20 non-null object
# Minimum     20 non-null float64
# Maximum     20 non-null float64
# Rainfall    20 non-null object
# dtypes: float64(2), object(2)
# memory usage: 720.0+ bytes

# %%
mdf = dataframe.loc[:, "Station":"Rainfall"]

# %%
mdf2 = dataframe2.loc[:, "Name":"Total"]

# %%
mdf.head()
# Out:
#          Station Rainfall
# 0        Dipayal      3.2
# 1     Dadeldhura     13.0
# 2       Dhangadi     18.8
# 3  Birendranagar      0.3
# 4      Nepalgunj      1.2

# %%
mdf["Rainfall"] == '3.2'
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Rainfall, dtype: bool

# %%
mdf2
# Out:
#                           Name    Type 1  Type 2  Total
# 0                    Bulbasaur     Grass  Poison    318
# 1                      Ivysaur     Grass  Poison    405
# 2                     Venusaur     Grass  Poison    525
# 3        VenusaurMega Venusaur     Grass  Poison    625
# 4                   Charmander      Fire     NaN    309
# 5                   Charmeleon      Fire     NaN    405
# 6                    Charizard      Fire  Flying    534
# 7    CharizardMega Charizard X      Fire  Dragon    634
# 8    CharizardMega Charizard Y      Fire  Flying    634
# 9                     Squirtle     Water     NaN    314
# 10                   Wartortle     Water     NaN    405
# 11                   Blastoise     Water     NaN    530
# 12     BlastoiseMega Blastoise     Water     NaN    630
# 13                    Caterpie       Bug     NaN    195
# 14                     Metapod       Bug     NaN    205
# 15                  Butterfree       Bug  Flying    395
# ...

# %%
mdf2.head()
# Out:
#                     Name Type 1  Type 2  Total
# 0              Bulbasaur  Grass  Poison    318
# 1                Ivysaur  Grass  Poison    405
# 2               Venusaur  Grass  Poison    525
# 3  VenusaurMega Venusaur  Grass  Poison    625
# 4             Charmander   Fire     NaN    309

# %%
mdf2["Type 1"] == 'Fire'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5       True
# 6       True
# 7       True
# 8       True
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 770    False
# 771    False
# 772    False
# 773    False
# 774    False
# 775    False
# 776    False
# 777    False
# 778    False
# 779    False
# 780    False
# 781    False
# 782    False
# 783    False
# 784    False
# 785    False
# 786    False
# 787    False
# 788    False
# 789    False
# 790    False
# 791    False
# 792    False
# 793    False
# 794    False
# 795    False
# 796    False
# 797    False
# 798    False
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
mdf2[mdf2["Type 1"] == 'Fire']
# Out:
#                           Name Type 1    Type 2  Total
# 4                   Charmander   Fire       NaN    309
# 5                   Charmeleon   Fire       NaN    405
# 6                    Charizard   Fire    Flying    534
# 7    CharizardMega Charizard X   Fire    Dragon    634
# 8    CharizardMega Charizard Y   Fire    Flying    634
# 42                      Vulpix   Fire       NaN    299
# 43                   Ninetales   Fire       NaN    505
# 63                   Growlithe   Fire       NaN    350
# 64                    Arcanine   Fire       NaN    555
# 83                      Ponyta   Fire       NaN    410
# 84                    Rapidash   Fire       NaN    500
# 135                     Magmar   Fire       NaN    495
# 147                    Flareon   Fire       NaN    525
# 158                    Moltres   Fire    Flying    580
# 169                  Cyndaquil   Fire       NaN    309
# 170                    Quilava   Fire       NaN    405
# ...

# %%
mdf2[mdf2["Type 1"] == 'Fire'].count()
# Out:
# Name      52
# Type 1    52
# Type 2    24
# Total     52
# dtype: int64

# %%
mdf2[(mdf2["Type 1"] == 'Fire') & (mdf2["Type 2"] == 'Flying')]
# Out:
#                           Name Type 1  Type 2  Total
# 6                    Charizard   Fire  Flying    534
# 8    CharizardMega Charizard Y   Fire  Flying    634
# 158                    Moltres   Fire  Flying    580
# 270                      Ho-oh   Fire  Flying    680
# 730                Fletchinder   Fire  Flying    382
# 731                 Talonflame   Fire  Flying    499

# %%
mdf2.max()
# Out:
# Name      Zygarde50% Forme
# Type 1               Water
# Total                  780
# dtype: object

# %%
dataframe2.max()
# Out:
# #                          721
# Name          Zygarde50% Forme
# Type 1                   Water
# Total                      780
# HP                         255
# Attack                     190
# Defense                    230
# Sp. Atk                    194
# Sp. Def                    230
# Speed                      180
# Generation                   6
# Legendary                 True
# dtype: object

# %%
dataframe2[160:165]
# Out:
#        #                 Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 160  148            Dragonair   Dragon       NaN    420   61      84       65
# 161  149            Dragonite   Dragon    Flying    600   91     134       95
# 162  150               Mewtwo  Psychic       NaN    680  106     110       90
# 163  150  MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 164  150  MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 160       70       70     70           1      False
# 161      100      100     80           1      False
# 162      154       90    130           1       True
# 163      154      100    130           1       True
# 164      194      120    140           1       True

# %%
mdf2['Total'].max() #Finds the data having maximum Total
# Out:
# 780

# %%
mdf2['Total'].idxmax() #finds the index of the Total having maximum number
# Out:
# 163

# %%
mdf2.loc[[mdf['Total'].idxmax()]] #DATAFRAME OUTPUT
# Out:
#                     Name   Type 1    Type 2  Total
# 163  MewtwoMega Mewtwo X  Psychic  Fighting    780

# %%
type(mdf2.loc[[mdf['Total'].idxmax()]])
# Out:
# pandas.core.frame.DataFrame

# %%
mdf2.loc[mdf2['Total'].idxmax()] #SERIES OUTPUT
# Out:
# Name      MewtwoMega Mewtwo X
# Type 1                Psychic
# Type 2               Fighting
# Total                     780
# Name: 163, dtype: object

# %%
type(mdf2.loc[mdf2['Total'].idxmax()])
# Out:
# pandas.core.series.Series

# %%
mdf2.head(10)
# Out:
#                         Name Type 1  Type 2  Total
# 0                  Bulbasaur  Grass  Poison    318
# 1                    Ivysaur  Grass  Poison    405
# 2                   Venusaur  Grass  Poison    525
# 3      VenusaurMega Venusaur  Grass  Poison    625
# 4                 Charmander   Fire     NaN    309
# 5                 Charmeleon   Fire     NaN    405
# 6                  Charizard   Fire  Flying    534
# 7  CharizardMega Charizard X   Fire  Dragon    634
# 8  CharizardMega Charizard Y   Fire  Flying    634
# 9                   Squirtle  Water     NaN    314

# %%
mdf2.groupby(["Type 1"])

# %%
mdf2[["Type 1", "Total"]].groupby(["Type 1"]).mean()
# Out:
#                Total
# Type 1
# Bug       378.927536
# Dark      445.741935
# Dragon    550.531250
# Electric  443.409091
# Fairy     413.176471
# Fighting  416.444444
# Fire      458.076923
# Flying    485.000000
# Ghost     439.562500
# Grass     421.142857
# Ground    437.500000
# Ice       433.458333
# Normal    401.683673
# Poison    399.142857
# Psychic   475.947368
# Rock      453.750000
# Steel     487.703704
# Water     430.455357

# %%
mdf2[["Type 1", "Total"]].groupby(["Type 1"]).mean().plot(kind='bar')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
mdf2[["Type 1", "Total"]].groupby(["Type 1"]).mean().plot(kind='bar')

# %%
import seaborn as sns

# %%
sns.set()

# %%
mdf2[["Type 1", "Total"]].groupby(["Type 1"]).mean().plot(kind='bar')
